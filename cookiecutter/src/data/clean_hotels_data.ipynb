# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import re

# %%
hotels_df = pd.read_csv('../../data/raw/hotels.csv')
hotels_df.head()
# Out:
#                                         listing_name  \
# 0  Holiday Inn Express & Suites Ottawa Downtown E...
# 1  Microtel Inn & Suites by Wyndham Kanata Ottawa...
# 2                                   Lord Elgin Hotel
# 3  Fairfield Inn & Suites by Marriott Ottawa Airport
# 4                            Welcominns Hotel Ottawa
#
#                        amenities                              rate  \
# 0         Breakfast includedPool    8.2/10Very good(1,219 reviews)
# 1             Breakfast included      8.6/10Excellent(176 reviews)
# 2                    PoolHot tub    8.6/10Excellent(1,031 reviews)
# 3  Breakfast includedPoolHot tub  9.4/10Exceptional(1,120 reviews)
# 4             Breakfast included         7.8/10Good(1,024 reviews)
#
#                                                price  \
# 0  Price is CA $180 per nightCA $180per nightCA $...
# 1  Price is CA $152 per nightCA $152per nightCA $...
# 2  12% offPrice was CA $339, price is now CA $298...
# 3  Price is CA $169 per nightCA $169per nightCA $...
# 4  Price is CA $169 per nightCA $169per nightCA $...
#
#                                         listing_link
# 0  ca.hotels.com/ho1177609504/holiday-inn-express...
# 1  ca.hotels.com/ho2321835040/microtel-inn-suites...
# 2  ca.hotels.com/ho111693/lord-elgin-hotel-ottawa...
# 3  ca.hotels.com/ho763070976/fairfield-inn-suites...
# 4  ca.hotels.comhttps://ca.hotels.com/user/signin...

# %%
# Function to insert space before upper case 

def add_space_before_uppercase(word):
    if isinstance(word, str):
        pattern = r'([a-z0-9])([A-Z])'
        result = re.sub(pattern, r'\1 \2', word)
        return result
    else:
        return word


# Apply the function to the 'amenities' column
hotels_df['amenities'] = hotels_df['amenities'].apply(add_space_before_uppercase)

# Apply the function to the 'rate' column
hotels_df['rate'] = hotels_df['rate'].apply(add_space_before_uppercase)

# Print the modified dataframe
hotels_df.head()
# Out:
#                                         listing_name  \
# 0  Holiday Inn Express & Suites Ottawa Downtown E...
# 1  Microtel Inn & Suites by Wyndham Kanata Ottawa...
# 2                                   Lord Elgin Hotel
# 3  Fairfield Inn & Suites by Marriott Ottawa Airport
# 4                            Welcominns Hotel Ottawa
#
#                          amenities                               rate  \
# 0          Breakfast included Pool    8.2/10 Very good(1,219 reviews)
# 1               Breakfast included      8.6/10 Excellent(176 reviews)
# 2                     Pool Hot tub    8.6/10 Excellent(1,031 reviews)
# 3  Breakfast included Pool Hot tub  9.4/10 Exceptional(1,120 reviews)
# 4               Breakfast included         7.8/10 Good(1,024 reviews)
#
#                                                price  \
# 0  Price is CA $180 per nightCA $180per nightCA $...
# 1  Price is CA $152 per nightCA $152per nightCA $...
# 2  12% offPrice was CA $339, price is now CA $298...
# 3  Price is CA $169 per nightCA $169per nightCA $...
# 4  Price is CA $169 per nightCA $169per nightCA $...
#
#                                         listing_link
# 0  ca.hotels.com/ho1177609504/holiday-inn-express...
# 1  ca.hotels.com/ho2321835040/microtel-inn-suites...
# 2  ca.hotels.com/ho111693/lord-elgin-hotel-ottawa...
# 3  ca.hotels.com/ho763070976/fairfield-inn-suites...
# 4  ca.hotels.comhttps://ca.hotels.com/user/signin...

# %% [markdown]
# ## Find the nightly price (before taxes & fees)

# %%
# Function to extract the nightly price before taxes & fees 

def extract_number_before_pernight(text):
    pattern = r'(\d+)\s*per\s*night\s*CA'
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))
    else:
        return None


# Apply the function to the 'price' column
hotels_df['nightly_price'] = hotels_df['price'].apply(extract_number_before_pernight)

# Print the modified dataframe
hotels_df.head()
# Out:
#                                         listing_name  \
# 0  Holiday Inn Express & Suites Ottawa Downtown E...
# 1  Microtel Inn & Suites by Wyndham Kanata Ottawa...
# 2                                   Lord Elgin Hotel
# 3  Fairfield Inn & Suites by Marriott Ottawa Airport
# 4                            Welcominns Hotel Ottawa
#
#                          amenities                               rate  \
# 0          Breakfast included Pool    8.2/10 Very good(1,219 reviews)
# 1               Breakfast included      8.6/10 Excellent(176 reviews)
# 2                     Pool Hot tub    8.6/10 Excellent(1,031 reviews)
# 3  Breakfast included Pool Hot tub  9.4/10 Exceptional(1,120 reviews)
# 4               Breakfast included         7.8/10 Good(1,024 reviews)
#
#                                                price  \
# 0  Price is CA $180 per nightCA $180per nightCA $...
# 1  Price is CA $152 per nightCA $152per nightCA $...
# 2  12% offPrice was CA $339, price is now CA $298...
# 3  Price is CA $169 per nightCA $169per nightCA $...
# 4  Price is CA $169 per nightCA $169per nightCA $...
#
#                                         listing_link  nightly_price
# 0  ca.hotels.com/ho1177609504/holiday-inn-express...            180
# 1  ca.hotels.com/ho2321835040/microtel-inn-suites...            152
# 2  ca.hotels.com/ho111693/lord-elgin-hotel-ottawa...            298
# 3  ca.hotels.com/ho763070976/fairfield-inn-suites...            169
# 4  ca.hotels.comhttps://ca.hotels.com/user/signin...            169

# %% [markdown]
# # Find the nightly_price (after taxes & fees)

# %%
# Function to extract the nightly price after taxes & fees 

def extract_number_before_total_includes(text):
    pattern = r'(\d+)\s*totalIncludes'
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))
    else:
        return None
    
# Apply the function to the 'price' column
hotels_df['taxable_price'] = hotels_df['price'].apply(extract_number_before_total_includes)

# Print the modified dataframe
hotels_df.head()
# Out:
#                                         listing_name  \
# 0  Holiday Inn Express & Suites Ottawa Downtown E...
# 1  Microtel Inn & Suites by Wyndham Kanata Ottawa...
# 2                                   Lord Elgin Hotel
# 3  Fairfield Inn & Suites by Marriott Ottawa Airport
# 4                            Welcominns Hotel Ottawa
#
#                          amenities                               rate  \
# 0          Breakfast included Pool    8.2/10 Very good(1,219 reviews)
# 1               Breakfast included      8.6/10 Excellent(176 reviews)
# 2                     Pool Hot tub    8.6/10 Excellent(1,031 reviews)
# 3  Breakfast included Pool Hot tub  9.4/10 Exceptional(1,120 reviews)
# 4               Breakfast included         7.8/10 Good(1,024 reviews)
#
#                                                price  \
# 0  Price is CA $180 per nightCA $180per nightCA $...
# 1  Price is CA $152 per nightCA $152per nightCA $...
# 2  12% offPrice was CA $339, price is now CA $298...
# 3  Price is CA $169 per nightCA $169per nightCA $...
# 4  Price is CA $169 per nightCA $169per nightCA $...
#
#                                         listing_link  nightly_price  \
# 0  ca.hotels.com/ho1177609504/holiday-inn-express...            180
# 1  ca.hotels.com/ho2321835040/microtel-inn-suites...            152
# 2  ca.hotels.com/ho111693/lord-elgin-hotel-ottawa...            298
# 3  ca.hotels.com/ho763070976/fairfield-inn-suites...            169
# 4  ca.hotels.comhttps://ca.hotels.com/user/signin...            169
#
#    taxable_price
# 0            212
# 1            179
# 2            351
# 3            199
# 4            199

# %% [markdown]
# # Extract rating over 10

# %%
# Function to extract rating over 10 from rate column 

def extract_number_before_rating(text):
    if isinstance(text, str):
        pattern = r'(\d+(?:\.\d+)?)\/10'
        match = re.search(pattern, text)
        if match:
            return float(match.group(1))
        else:
            return None
    else:
        return None

# Apply the function to the 'rate' column
hotels_df['rating_10'] = hotels_df['rate'].apply(extract_number_before_rating)

# Print the modified dataframe
hotels_df.head()
# Out:
#                                         listing_name  \
# 0  Holiday Inn Express & Suites Ottawa Downtown E...
# 1  Microtel Inn & Suites by Wyndham Kanata Ottawa...
# 2                                   Lord Elgin Hotel
# 3  Fairfield Inn & Suites by Marriott Ottawa Airport
# 4                            Welcominns Hotel Ottawa
#
#                          amenities                               rate  \
# 0          Breakfast included Pool    8.2/10 Very good(1,219 reviews)
# 1               Breakfast included      8.6/10 Excellent(176 reviews)
# 2                     Pool Hot tub    8.6/10 Excellent(1,031 reviews)
# 3  Breakfast included Pool Hot tub  9.4/10 Exceptional(1,120 reviews)
# 4               Breakfast included         7.8/10 Good(1,024 reviews)
#
#                                                price  \
# 0  Price is CA $180 per nightCA $180per nightCA $...
# 1  Price is CA $152 per nightCA $152per nightCA $...
# 2  12% offPrice was CA $339, price is now CA $298...
# 3  Price is CA $169 per nightCA $169per nightCA $...
# 4  Price is CA $169 per nightCA $169per nightCA $...
#
#                                         listing_link  nightly_price  \
# 0  ca.hotels.com/ho1177609504/holiday-inn-express...            180
# 1  ca.hotels.com/ho2321835040/microtel-inn-suites...            152
# 2  ca.hotels.com/ho111693/lord-elgin-hotel-ottawa...            298
# 3  ca.hotels.com/ho763070976/fairfield-inn-suites...            169
# 4  ca.hotels.comhttps://ca.hotels.com/user/signin...            169
#
#    taxable_price  rating_10
# 0            212        8.2
# 1            179        8.6
# 2            351        8.6
# 3            199        9.4
# 4            199        7.8

# %% [markdown]
# # Extract the number of reviews

# %%
# Function to extract number of reviews from rate column 

def extract_number_before_reviews(text):
    if isinstance(text, str):
        pattern = pattern = r'(\d+(?:,\d+)?) reviews'
        match = re.search(pattern, text)
        if match:
            number = match.group(1).replace(',', '')
            return int(number)
        else:
            return None
    else:
        return None

# Apply the function to the 'rate' column
hotels_df['nb_reviews'] = hotels_df['rate'].apply(extract_number_before_reviews)

# Print the modified dataframe
hotels_df.head()
# Out:
#                                         listing_name  \
# 0  Holiday Inn Express & Suites Ottawa Downtown E...
# 1  Microtel Inn & Suites by Wyndham Kanata Ottawa...
# 2                                   Lord Elgin Hotel
# 3  Fairfield Inn & Suites by Marriott Ottawa Airport
# 4                            Welcominns Hotel Ottawa
#
#                          amenities                               rate  \
# 0          Breakfast included Pool    8.2/10 Very good(1,219 reviews)
# 1               Breakfast included      8.6/10 Excellent(176 reviews)
# 2                     Pool Hot tub    8.6/10 Excellent(1,031 reviews)
# 3  Breakfast included Pool Hot tub  9.4/10 Exceptional(1,120 reviews)
# 4               Breakfast included         7.8/10 Good(1,024 reviews)
#
#                                                price  \
# 0  Price is CA $180 per nightCA $180per nightCA $...
# 1  Price is CA $152 per nightCA $152per nightCA $...
# 2  12% offPrice was CA $339, price is now CA $298...
# 3  Price is CA $169 per nightCA $169per nightCA $...
# 4  Price is CA $169 per nightCA $169per nightCA $...
#
#                                         listing_link  nightly_price  \
# 0  ca.hotels.com/ho1177609504/holiday-inn-express...            180
# 1  ca.hotels.com/ho2321835040/microtel-inn-suites...            152
# 2  ca.hotels.com/ho111693/lord-elgin-hotel-ottawa...            298
# 3  ca.hotels.com/ho763070976/fairfield-inn-suites...            169
# 4  ca.hotels.comhttps://ca.hotels.com/user/signin...            169
#
#    taxable_price  rating_10  nb_reviews
# 0            212        8.2      1219.0
# 1            179        8.6       176.0
# 2            351        8.6      1031.0
# 3            199        9.4      1120.0
# 4            199        7.8      1024.0

# %%
# Drop rate and price column 
columns_to_drop = ['rate', 'price']
hotels_df = hotels_df.drop(columns_to_drop, axis=1)

# Print the modified dataframe
hotels_df.head()
# Out:
#                                         listing_name  \
# 0  Holiday Inn Express & Suites Ottawa Downtown E...
# 1  Microtel Inn & Suites by Wyndham Kanata Ottawa...
# 2                                   Lord Elgin Hotel
# 3  Fairfield Inn & Suites by Marriott Ottawa Airport
# 4                            Welcominns Hotel Ottawa
#
#                          amenities  \
# 0          Breakfast included Pool
# 1               Breakfast included
# 2                     Pool Hot tub
# 3  Breakfast included Pool Hot tub
# 4               Breakfast included
#
#                                         listing_link  nightly_price  \
# 0  ca.hotels.com/ho1177609504/holiday-inn-express...            180
# 1  ca.hotels.com/ho2321835040/microtel-inn-suites...            152
# 2  ca.hotels.com/ho111693/lord-elgin-hotel-ottawa...            298
# 3  ca.hotels.com/ho763070976/fairfield-inn-suites...            169
# 4  ca.hotels.comhttps://ca.hotels.com/user/signin...            169
#
#    taxable_price  rating_10  nb_reviews
# 0            212        8.2      1219.0
# 1            179        8.6       176.0
# 2            351        8.6      1031.0
# 3            199        9.4      1120.0
# 4            199        7.8      1024.0

# %%
# Save cleaned dataframe as CSV file
hotels_df.to_csv('../clean_data/clean_hotels.csv',index=False)
